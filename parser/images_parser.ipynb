# %%
# !pip install icrawler
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/stuff/божьи коровки'
name = 'божья коровка фото'
quantity = 1000

# %%
bing_crawler = BingImageCrawler(storage={'root_dir': path})
bing_crawler.crawl(keyword=name, filters=None, offset=0, max_num=quantity)
# Out:
# ERROR:downloader:Response status code 404, file https://images.wallpaperscraft.ru/image/bozhya_korovka_rastenie_trava_83913_1280x720.jpg
# ERROR:downloader:Response status code 404, file https://images.wallpaperscraft.ru/image/bozhya_korovka_nasekomoe_pyatna_fon_68000_1280x720.jpg
# ERROR:downloader:Response status code 403, file http://funzoo.ru/uploads/posts/2009-07/1246902764_dsc020601.jpg
# ERROR:downloader:Response status code 404, file https://proimg.ru/wp-content/uploads/2018/08/67554AB87A3A5C5C5180DD7280090744-1200x1200-640x640.jpg
# ERROR:downloader:Response status code 404, file https://proimg.ru/wp-content/uploads/2018/08/bozhyakorovkam.jpg
# ERROR:downloader:Exception caught when downloading file https://drasler.ru/wp-content/uploads/2020/05/Картинка-божья-коровка-на-прозрачном-фоне-001.jpg, error: HTTPSConnectionPool(host='drasler.ru', port=443): Read timed out. (read timeout=5), remaining retry times: 2
# ...

# %%
google_crawler = GoogleImageCrawler(storage={'root_dir': path})
google_crawler.crawl(keyword=name, max_num=quantity)
# Out:
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/b/b2/Scandinavia1219.png
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Flags_of_%C3%85land_and_Finland.png
# ERROR:downloader:Response status code 400, file https://media.istockphoto.com/id/861220876/ru/%D1%84%D0%BE%D1%82%D0%BE/%D1%84%D0%BB%D0%B0%D0%B3-%D0%B0%D0%BB%D0%B0%D0%BD%D0%B4%D1%81%D0%BA%D0%B8%D1%85-%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B2%D0%BE%D0%B2-%D0%BD%D0%B0%D0%B4-%D0%B3%D0%BE%D0%BB%D1%83%D0%B1%D1%8B%D0%BC-%D0%BD%D0%B5%D0%B1%D0%BE%D0%BC-%D1%84%D0%B8%D0%BD%D0%BB%D1%8F%D0%BD%D0%B4%D0%B8%D1%8F-%D1%84%D0%BE%D0%BD.jpg
# ERROR:downloader:Response status code 404, file http://www.votpusk.ru/country/ctimages/new/Aland_Islands.jpg
# ERROR:downloader:Response status code 400, file https://media.istockphoto.com/id/482875650/photo/flag-of-aland-islands.jpg
