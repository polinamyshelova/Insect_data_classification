# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install difPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from difPy import dif

# %%
search = dif('/content/drive/MyDrive/insects data/Ladybird', show_output=True, delete=True)
# Out:
# difPy preparing files: [683/683] [100%]
# Files:
# ...rive/insects data/Ladybird/Ladybird (109).jpg and
# ...rive/insects data/Ladybird/Ladybird (106).jpg
#
# difPy comparing images: [7/683] [1%]
# Files:
# ...rive/insects data/Ladybird/Ladybird (131).jpg and
# ...Drive/insects data/Ladybird/Ladybird (91).jpg
# Files:
# ...Drive/insects data/Ladybird/Ladybird (93).jpg and
# ...Drive/insects data/Ladybird/Ladybird (16).jpg
# Files:
# ...rive/insects data/Ladybird/Ladybird (105).jpg and
# ...rive/insects data/Ladybird/Ladybird (108).jpg
# Files:
# ...rive/insects data/Ladybird/Ladybird (107).jpg and
# ...rive/insects data/Ladybird/Ladybird (110).jpg
# Files:
# ...rive/insects data/Ladybird/Ladybird (135).jpg and
# ...Drive/insects data/Ladybird/Ladybird (86).jpg
#
# difPy comparing images: [26/683] [4%]
# Files:
# ...Drive/insects data/Ladybird/Ladybird (96).jpg and
# ...Drive/insects data/Ladybird/Ladybird (18).jpg
# Files:
# ...Drive/insects data/Ladybird/Ladybird (88).jpg and
# ...

# %%
search = dif('/content/drive/MyDrive/insects data/Butterfly', show_output=True, delete=True)
# Out:
# difPy preparing files: [1098/1098] [100%]
# difPy comparing images: [1098/1098] [100%]
# Found 0 pair(s) of duplicate image(s) in 228.133 seconds.

# %%
search = dif('/content/drive/MyDrive/insects data/Dragonfly', show_output=True, delete=True)
# Out:
# difPy preparing files: [910/910] [100%]
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (128).jpg and
# ...ve/insects data/Dragonfly/Dragonfly (209).jpg
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (128).jpg and
# ...ve/insects data/Dragonfly/Dragonfly (343).jpg
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (129).jpg and
# ...ve/insects data/Dragonfly/Dragonfly (234).jpg
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (129).jpg and
# ...ve/insects data/Dragonfly/Dragonfly (367).jpg
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (206).jpg and
# ...ve/insects data/Dragonfly/Dragonfly (103).jpg
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (206).jpg and
# ...ve/insects data/Dragonfly/Dragonfly (320).jpg
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (132).jpg and
# ...ve/insects data/Dragonfly/Dragonfly (257).jpg
# Files:
# ...ve/insects data/Dragonfly/Dragonfly (132).jpg and
# ...ive/insects data/Dragonfly/Dragonfly (27).jpg
# Files:
# ...

# %%
search = dif('/content/drive/MyDrive/insects data/Grasshopper', show_output=True, delete=True)
# Out:
# difPy preparing files: [607/607] [100%]
# difPy comparing images: [607/607] [100%]
# Found 0 pair(s) of duplicate image(s) in 64.9315 seconds.

# %%
search = dif('/content/drive/MyDrive/insects data/Mosquito', show_output=True, delete=True)
# Out:
# difPy preparing files: [560/560] [100%]
# Files:
# ...rive/insects data/Mosquito/Mosquito (381).jpg and
# ...rive/insects data/Mosquito/Mosquito (368).jpg
# Files:
# ...rive/insects data/Mosquito/Mosquito (115).jpg and
# ...rive/insects data/Mosquito/Mosquito (261).jpg
# Files:
# ...rive/insects data/Mosquito/Mosquito (115).jpg and
# ...rive/insects data/Mosquito/Mosquito (395).jpg
# Files:
# ...rive/insects data/Mosquito/Mosquito (253).jpg and
# ...rive/insects data/Mosquito/Mosquito (333).jpg
# Files:
# ...Drive/insects data/Mosquito/Mosquito (59).jpg and
# ...rive/insects data/Mosquito/Mosquito (131).jpg
# Files:
# ...rive/insects data/Mosquito/Mosquito (270).jpg and
# ...rive/insects data/Mosquito/Mosquito (327).jpg
# Files:
# ...rive/insects data/Mosquito/Mosquito (287).jpg and
# ...rive/insects data/Mosquito/Mosquito (300).jpg
# Files:
# ...rive/insects data/Mosquito/Mosquito (283).jpg and
# ...rive/insects data/Mosquito/Mosquito (138).jpg
# Files:
# ...
